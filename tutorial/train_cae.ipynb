# %% [markdown]
# # Autoencoder
#
# This file contains all the necessary steps to train the CAE for the L22

# %%
import matplotlib as mpl
from pathlib import Path
import torchinfo
import torch
import time
import einops
import h5py
import sys
import matplotlib.pyplot as plt
import numpy as np
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)
device = torch.device("cuda:2")
mpl.rc('text', usetex=True)
mpl.rc('font', family='serif')

# %%
sys.path.append('../')
from src.neuralnetwork.autoencoder import CAE
from src.neuralnetwork.preprocessing import normalize_data, train_valid_test_split
from src.neuralnetwork.earlystopping import EarlyStopper
from src.neuralnetwork.losses import LossTracker

# %% [markdown]
# #### 1 Data Import
# 1. Load the data
# 2. Discard the transient
# 3. Normalize and split the data

# %%
# Define some parameters for the data
N_lyap = int(1/0.08/0.05)
ks_data = {
    'L': 22,
    'N_data': 200000,
    'N_trans': 1000,
    'dt': 0.05,
    'Nx': 512,
    'train_ratio': 100*N_lyap/200000,
    'valid_ratio': 100*N_lyap/200000,
    'batchsize': 128,
    'normtype': 'max', 
    'lyap':0.08, 
    'upsample':5
}

# %%
f = h5py.File('/storage0/eo821/KS/L22/M256_N512_tmax100000_deltat0.05L22.mat','r')
U = np.array(f.get('uu'))[:, 1000::ks_data['upsample']] 
U = einops.rearrange(U, 'x time-> time 1 x')
sysdim = U.shape[0]
print(f"Shape of KS data: {U.shape}")

# Normalize and split
U_normalized, maxnorm = normalize_data(U, normtype=ks_data['normtype'])
U_train_series, U_valid_series, U_test_series = train_valid_test_split(U_normalized, ks_data)

train_loader = torch.utils.data.DataLoader(torch.from_numpy(U_train_series).float(), batch_size=ks_data['batchsize'])
valid_loader = torch.utils.data.DataLoader(torch.from_numpy(U_valid_series).float(), batch_size=ks_data['batchsize'])
# Out:
# Shape of KS data: (399801, 1, 512)

# %% [markdown]
# #### 2 Convolutional Autoencoder
# 1. Load the class and set the number of latent variables
# 2. Train the CAE
# 3. (opt) Load pretrained weights

# %%
cae_model = CAE(8)
cae_model = cae_model.to(device)
print(torchinfo.summary(cae_model, input_size=(1, 1, ks_data['Nx'])))

criterion = torch.nn.MSELoss()
optimizer = torch.optim.Adam(cae_model.parameters(), lr=0.001)
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# CAE                                      [1, 8]                    --
# ├─Sequential: 1-1                        [1, 8]                    --
# │    └─Conv1d: 2-1                       [1, 2, 253]               18
# │    └─Tanh: 2-2                         [1, 2, 253]               --
# │    └─Conv1d: 2-3                       [1, 4, 123]               68
# │    └─Tanh: 2-4                         [1, 4, 123]               --
# │    └─Conv1d: 2-5                       [1, 8, 60]                168
# │    └─Tanh: 2-6                         [1, 8, 60]                --
# │    └─Conv1d: 2-7                       [1, 16, 19]               656
# │    └─Tanh: 2-8                         [1, 16, 19]               --
# │    └─Conv1d: 2-9                       [1, 32, 6]                1,568
# │    └─Tanh: 2-10                        [1, 32, 6]                --
# │    └─Conv1d: 2-11                      [1, 64, 2]                6,208
# │    └─Tanh: 2-12                        [1, 64, 2]                --
# │    └─Flatten: 2-13                     [1, 128]                  --
# │    └─Linear: 2-14                      [1, 8]                    1,032
# │    └─Tanh: 2-15                        [1, 8]                    --
# ├─Sequential: 1-2                        [1, 1, 512]               --
# │    └─Linear: 2-16                      [1, 128]                  1,152
# │    └─Tanh: 2-17                        [1, 128]                  --
# │    └─Unflatten: 2-18                   [1, 64, 2]                --
# │    └─ConvTranspose1d: 2-19             [1, 32, 6]                6,176
# │    └─ConvTranspose1d: 2-20             [1, 32, 8]                3,104
# │    └─Tanh: 2-21                        [1, 32, 8]                --
# │    └─ConvTranspose1d: 2-22             [1, 16, 26]               2,576
# │    └─ConvTranspose1d: 2-23             [1, 16, 26]               784
# │    └─Tanh: 2-24                        [1, 16, 26]               --
# │    └─ConvTranspose1d: 2-25             [1, 8, 80]                648
# │    └─ConvTranspose1d: 2-26             [1, 8, 82]                200
# │    └─Tanh: 2-27                        [1, 8, 82]                --
# │    └─ConvTranspose1d: 2-28             [1, 4, 251]               260
# │    └─ConvTranspose1d: 2-29             [1, 4, 253]               52
# │    └─Tanh: 2-30                        [1, 4, 253]               --
# │    └─ConvTranspose1d: 2-31             [1, 2, 512]               66
# │    └─ConvTranspose1d: 2-32             [1, 1, 512]               7
# │    └─Tanh: 2-33                        [1, 1, 512]               --
# ==========================================================================================
# Total params: 24,743
# Trainable params: 24,743
# Non-trainable params: 0
# Total mult-adds (M): 0.39
# ==========================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.07
# Params size (MB): 0.10
# Estimated Total Size (MB): 0.17
# ==========================================================================================

# %%
# # Load model weights if available
# model_path = Path('/home/eo821/Documents/Kolmogorov-CAE-RNN/models/ks/L8pi/fluent-sweep-2')
# cae_model.load_state_dict(torch.load(model_path/"best_model.pth", map_location=device))
# cae_model = cae_model.to(device)

# %%
model_path = Path('../weights/fluent-sweep-2/')

# %%
# Define the number of epochs and the gamma parameter for the scheduler
epochs = 100
gamma = 0.999

# Create an instance of ExponentialLR and associate it with your optimizer
scheduler = torch.optim.lr_scheduler.ExponentialLR(optimizer, gamma=gamma)
loss_tracker = LossTracker(len(train_loader), len(valid_loader))

early_stopper = EarlyStopper(patience=200, min_delta=1e-6)
weighing_dissipation = 1
cae_model = cae_model.to(device)
# wandb.watch(model)
best_model_state_dict = cae_model.state_dict()  # Save the best model state_dict
patience = 100
training_losses_per_epoch = []
validation_losses_per_epoch = []
best_validation_loss = float('inf')
for epoch in range(epochs):
    loss_tracker.set_start_time(time.time())
    loss_tracker.reset_current_loss()

    # Training loop
    cae_model.train()
    for step, x_batch_train in enumerate(train_loader):
        x_batch_train = x_batch_train.to(device)
        optimizer.zero_grad()
        encoded, output = cae_model(x_batch_train.to(device))
        loss = criterion(output, x_batch_train)
        loss.backward()
        optimizer.step()
        loss_tracker.update_current_loss('training', loss)
    loss_tracker.print_current_loss(epoch, 'training')

    loss_tracker.set_start_time(time.time())
    scheduler.step()
    # Validation loop
    cae_model.eval()
    with torch.no_grad():
        for valid_step, x_batch_valid in enumerate(valid_loader):
            x_batch_valid = x_batch_valid.to(device)
            encoded, output = cae_model(x_batch_valid)
            loss = criterion(output, x_batch_valid)
            loss_tracker.update_current_loss('validation', loss)

    loss_tracker.print_current_loss(epoch, 'validation')
    loss_tracker.calculate_and_store_average_losses()

    if loss_tracker.check_best_validation_loss():
        early_stopper.reset_counter()
        best_model_state_dict = cae_model.state_dict()  # the best model state_dict
        torch.save(cae_model.state_dict(), model_path/'best_model.pth')  # Save the best model
        print('Saved best model')
    if early_stopper.track(loss_tracker.get_current_validation_loss()):
        break
# Out:
# training; epoch 0; time 2.73s
# total loss 7.20e-02
# validation; epoch 0; time 0.29s
# total loss 3.49e-02
# Saved best model
# training; epoch 1; time 2.59s
# total loss 2.48e-02
# validation; epoch 1; time 0.69s
# total loss 2.31e-02
# Saved best model
# training; epoch 2; time 2.29s
# total loss 1.71e-02
# validation; epoch 2; time 0.37s
# total loss 1.48e-02
# Saved best model
# training; epoch 3; time 1.29s
# total loss 1.04e-02
# validation; epoch 3; time 0.29s
# total loss 9.19e-03
# Saved best model
# training; epoch 4; time 2.63s
# total loss 6.85e-03
# validation; epoch 4; time 0.32s
# total loss 7.02e-03
# Saved best model
# training; epoch 5; time 2.39s
# total loss 6.46e-03
# validation; epoch 5; time 0.49s
# total loss 4.79e-03
# Saved best model
# training; epoch 6; time 1.77s
# total loss 5.22e-03
# validation; epoch 6; time 0.39s
# total loss 5.50e-03
# training; epoch 7; time 2.22s
# total loss 4.90e-03
# validation; epoch 7; time 0.31s
# total loss 5.16e-03
# training; epoch 8; time 2.62s
# total loss 4.33e-03
# validation; epoch 8; time 0.32s
# total loss 4.52e-03
# Saved best model
# training; epoch 9; time 2.32s
# total loss 3.98e-03
# validation; epoch 9; time 0.52s
# total loss 4.41e-03
# Saved best model
# training; epoch 10; time 1.39s
# total loss 3.87e-03
# validation; epoch 10; time 0.34s
# total loss 4.26e-03
# Saved best model
# training; epoch 11; time 2.13s
# total loss 3.42e-03
# validation; epoch 11; time 0.31s
# total loss 4.33e-03
# training; epoch 12; time 2.63s
# total loss 3.35e-03
# validation; epoch 12; time 0.32s
# total loss 4.11e-03
# Saved best model
# training; epoch 13; time 2.62s
# total loss 3.28e-03
# validation; epoch 13; time 0.30s
# total loss 3.96e-03
# Saved best model
# training; epoch 14; time 2.62s
# total loss 3.26e-03
# validation; epoch 14; time 0.31s
# total loss 3.62e-03
# Saved best model
# training; epoch 15; time 2.62s
# total loss 2.98e-03
# validation; epoch 15; time 0.31s
# total loss 3.42e-03
# Saved best model
# training; epoch 16; time 2.64s
# total loss 3.31e-03
# validation; epoch 16; time 0.47s
# total loss 3.28e-03
# Saved best model
# training; epoch 17; time 1.97s
# total loss 2.49e-03
# validation; epoch 17; time 0.30s
# total loss 3.58e-03
# training; epoch 18; time 1.74s
# total loss 3.30e-03
# validation; epoch 18; time 0.30s
# total loss 3.92e-03
# training; epoch 19; time 2.57s
# total loss 2.98e-03
# validation; epoch 19; time 0.30s
# total loss 3.62e-03
# training; epoch 20; time 2.19s
# total loss 2.21e-03
# validation; epoch 20; time 0.32s
# total loss 2.67e-03
# Saved best model
# training; epoch 21; time 2.56s
# total loss 2.80e-03
# validation; epoch 21; time 0.30s
# total loss 2.74e-03
# training; epoch 22; time 2.58s
# total loss 2.32e-03
# validation; epoch 22; time 0.29s
# total loss 2.56e-03
# Saved best model
# training; epoch 23; time 2.61s
# total loss 2.24e-03
# validation; epoch 23; time 0.31s
# total loss 2.51e-03
# Saved best model
# training; epoch 24; time 2.58s
# total loss 2.07e-03
# validation; epoch 24; time 0.54s
# total loss 2.34e-03
# Saved best model
# training; epoch 25; time 2.36s
# total loss 2.14e-03
# validation; epoch 25; time 0.30s
# total loss 2.02e-03
# Saved best model
# training; epoch 26; time 2.57s
# total loss 1.87e-03
# validation; epoch 26; time 0.31s
# total loss 2.47e-03
# training; epoch 27; time 2.63s
# total loss 2.07e-03
# validation; epoch 27; time 0.31s
# total loss 2.57e-03
# training; epoch 28; time 2.64s
# total loss 2.15e-03
# validation; epoch 28; time 0.29s
# total loss 1.88e-03
# Saved best model
# training; epoch 29; time 2.60s
# total loss 2.04e-03
# validation; epoch 29; time 0.30s
# total loss 1.82e-03
# Saved best model
# training; epoch 30; time 2.61s
# total loss 2.20e-03
# validation; epoch 30; time 0.30s
# total loss 2.41e-03
# training; epoch 31; time 2.61s
# total loss 2.99e-03
# validation; epoch 31; time 0.31s
# total loss 2.05e-03
# training; epoch 32; time 2.61s
# total loss 1.66e-03
# validation; epoch 32; time 0.29s
# total loss 2.23e-03
# training; epoch 33; time 2.61s
# total loss 1.82e-03
# validation; epoch 33; time 0.30s
# total loss 1.92e-03
# training; epoch 34; time 2.63s
# total loss 1.86e-03
# validation; epoch 34; time 0.30s
# total loss 1.51e-03
# Saved best model
# training; epoch 35; time 2.62s
# total loss 1.85e-03
# validation; epoch 35; time 0.31s
# total loss 4.03e-03
# training; epoch 36; time 2.63s
# total loss 3.35e-03
# validation; epoch 36; time 0.30s
# total loss 2.60e-03
# training; epoch 37; time 2.62s
# total loss 1.29e-03
# validation; epoch 37; time 0.30s
# total loss 1.21e-03
# Saved best model
# training; epoch 38; time 2.62s
# total loss 1.16e-03
# validation; epoch 38; time 0.30s
# total loss 1.71e-03
# training; epoch 39; time 2.61s
# total loss 1.51e-03
# validation; epoch 39; time 0.31s
# total loss 1.94e-03
# training; epoch 40; time 2.63s
# total loss 2.11e-03
# validation; epoch 40; time 0.31s
# total loss 1.35e-03
# training; epoch 41; time 2.61s
# total loss 1.20e-03
# validation; epoch 41; time 0.31s
# total loss 1.87e-03
# training; epoch 42; time 2.64s
# total loss 1.67e-03
# validation; epoch 42; time 0.30s
# total loss 1.31e-03
# training; epoch 43; time 2.60s
# total loss 1.72e-03
# validation; epoch 43; time 0.29s
# total loss 1.31e-03
# training; epoch 44; time 2.62s
# total loss 9.58e-04
# validation; epoch 44; time 0.29s
# total loss 1.14e-03
# Saved best model
# training; epoch 45; time 2.61s
# total loss 9.80e-04
# validation; epoch 45; time 0.29s
# total loss 1.56e-03
# training; epoch 46; time 2.61s
# total loss 1.26e-03
# validation; epoch 46; time 0.29s
# total loss 1.71e-03
# training; epoch 47; time 2.64s
# total loss 1.47e-03
# validation; epoch 47; time 0.30s
# total loss 2.64e-03
# training; epoch 48; time 2.62s
# total loss 1.51e-03
# validation; epoch 48; time 0.29s
# total loss 1.06e-03
# Saved best model
# training; epoch 49; time 2.63s
# total loss 1.01e-03
# validation; epoch 49; time 0.29s
# total loss 9.20e-04
# Saved best model
# training; epoch 50; time 2.62s
# total loss 1.04e-03
# validation; epoch 50; time 0.30s
# total loss 1.22e-03
# training; epoch 51; time 2.63s
# total loss 1.12e-03
# validation; epoch 51; time 0.29s
# total loss 1.27e-03
# training; epoch 52; time 2.62s
# total loss 1.29e-03
# validation; epoch 52; time 0.29s
# total loss 1.23e-03
# training; epoch 53; time 2.64s
# total loss 1.36e-03
# validation; epoch 53; time 0.31s
# total loss 1.47e-03
# training; epoch 54; time 2.63s
# total loss 1.63e-03
# validation; epoch 54; time 0.30s
# total loss 1.27e-03
# training; epoch 55; time 2.61s
# total loss 1.14e-03
# validation; epoch 55; time 0.30s
# total loss 1.29e-03
# training; epoch 56; time 2.61s
# total loss 1.59e-03
# validation; epoch 56; time 0.30s
# total loss 1.28e-03
# training; epoch 57; time 2.62s
# total loss 1.50e-03
# validation; epoch 57; time 0.29s
# total loss 1.06e-03
# training; epoch 58; time 2.62s
# total loss 1.31e-03
# validation; epoch 58; time 0.30s
# total loss 1.15e-03
# training; epoch 59; time 2.62s
# total loss 9.80e-04
# validation; epoch 59; time 0.31s
# total loss 1.50e-03
# training; epoch 60; time 2.63s
# total loss 1.11e-03
# validation; epoch 60; time 0.30s
# total loss 1.47e-03
# training; epoch 61; time 2.63s
# total loss 1.21e-03
# validation; epoch 61; time 0.30s
# total loss 1.08e-03
# training; epoch 62; time 2.60s
# total loss 1.35e-03
# validation; epoch 62; time 0.30s
# total loss 7.43e-04
# Saved best model
# training; epoch 63; time 2.64s
# total loss 1.19e-03
# validation; epoch 63; time 0.30s
# total loss 1.97e-03
# training; epoch 64; time 2.61s
# total loss 1.73e-03
# validation; epoch 64; time 0.29s
# total loss 1.44e-03
# training; epoch 65; time 2.63s
# total loss 1.13e-03
# validation; epoch 65; time 0.30s
# total loss 9.77e-04
# training; epoch 66; time 2.61s
# total loss 8.39e-04
# validation; epoch 66; time 0.29s
# total loss 1.71e-03
# training; epoch 67; time 2.62s
# total loss 1.13e-03
# validation; epoch 67; time 0.30s
# total loss 9.82e-04
# training; epoch 68; time 2.61s
# total loss 8.54e-04
# validation; epoch 68; time 0.29s
# total loss 1.48e-03
# training; epoch 69; time 2.63s
# total loss 1.01e-03
# validation; epoch 69; time 0.29s
# total loss 1.05e-03
# training; epoch 70; time 2.62s
# total loss 8.81e-04
# validation; epoch 70; time 0.29s
# total loss 7.20e-04
# Saved best model
# training; epoch 71; time 2.62s
# total loss 8.22e-04
# validation; epoch 71; time 0.31s
# total loss 7.31e-04
# training; epoch 72; time 2.60s
# total loss 8.38e-04
# validation; epoch 72; time 0.30s
# total loss 7.67e-04
# training; epoch 73; time 2.60s
# total loss 9.86e-04
# validation; epoch 73; time 0.30s
# total loss 9.07e-04
# training; epoch 74; time 2.60s
# total loss 9.86e-04
# validation; epoch 74; time 0.30s
# total loss 6.54e-04
# Saved best model
# training; epoch 75; time 2.61s
# total loss 7.12e-04
# validation; epoch 75; time 0.35s
# total loss 6.65e-04
# training; epoch 76; time 2.09s
# total loss 8.59e-04
# validation; epoch 76; time 0.32s
# total loss 8.55e-04
# training; epoch 77; time 2.66s
# total loss 1.04e-03
# validation; epoch 77; time 0.31s
# total loss 9.53e-04
# training; epoch 78; time 2.61s
# total loss 9.95e-04
# validation; epoch 78; time 0.29s
# total loss 1.23e-03
# training; epoch 79; time 2.60s
# total loss 1.31e-03
# validation; epoch 79; time 0.29s
# total loss 7.79e-04
# training; epoch 80; time 2.61s
# total loss 8.58e-04
# validation; epoch 80; time 0.29s
# total loss 8.41e-04
# training; epoch 81; time 2.61s
# total loss 8.39e-04
# validation; epoch 81; time 0.29s
# total loss 9.26e-04
# training; epoch 82; time 2.66s
# total loss 7.30e-04
# validation; epoch 82; time 0.40s
# total loss 8.57e-04
# training; epoch 83; time 2.66s
# total loss 7.20e-04
# validation; epoch 83; time 0.31s
# total loss 7.19e-04
# training; epoch 84; time 1.99s
# total loss 7.09e-04
# validation; epoch 84; time 0.34s
# total loss 8.05e-04
# training; epoch 85; time 1.96s
# total loss 7.55e-04
# validation; epoch 85; time 0.30s
# total loss 6.33e-04
# Saved best model
# training; epoch 86; time 1.84s
# total loss 7.55e-04
# validation; epoch 86; time 0.37s
# total loss 8.11e-04
# training; epoch 87; time 2.60s
# total loss 8.12e-04
# validation; epoch 87; time 0.30s
# total loss 1.27e-03
# training; epoch 88; time 2.60s
# total loss 8.49e-04
# validation; epoch 88; time 0.30s
# total loss 9.13e-04
# training; epoch 89; time 2.61s
# total loss 7.50e-04
# validation; epoch 89; time 0.29s
# total loss 1.31e-03
# training; epoch 90; time 2.49s
# total loss 8.88e-04
# validation; epoch 90; time 0.32s
# total loss 8.46e-04
# training; epoch 91; time 2.26s
# total loss 8.32e-04
# validation; epoch 91; time 0.30s
# total loss 1.47e-03
# training; epoch 92; time 2.59s
# total loss 9.22e-04
# validation; epoch 92; time 0.30s
# total loss 8.12e-04
# training; epoch 93; time 2.61s
# total loss 6.33e-04
# validation; epoch 93; time 0.30s
# total loss 7.06e-04
# training; epoch 94; time 2.61s
# total loss 7.20e-04
# validation; epoch 94; time 0.30s
# total loss 1.00e-03
# training; epoch 95; time 2.60s
# total loss 8.68e-04
# validation; epoch 95; time 0.30s
# total loss 7.17e-04
# training; epoch 96; time 2.50s
# total loss 6.86e-04
# validation; epoch 96; time 0.43s
# total loss 6.82e-04
# training; epoch 97; time 1.95s
# total loss 6.22e-04
# validation; epoch 97; time 0.30s
# total loss 7.50e-04
# training; epoch 98; time 1.75s
# total loss 7.26e-04
# validation; epoch 98; time 0.30s
# total loss 8.61e-04
# training; epoch 99; time 2.60s
# total loss 8.06e-04
# validation; epoch 99; time 0.29s
# total loss 6.68e-04

# %%
# model_path = Path('../weights/100_LT_005/')
model_path.mkdir(parents=True, exist_ok=True)
# torch.save(cae_model.state_dict(), model_path/'best_model.pth')  
device_tmp = "cpu"
cae_model.load_state_dict(torch.load(model_path/"best_model.pth", map_location=device_tmp))
cae_model = cae_model.to(device_tmp)

# save the encoded data
snapshot = torch.from_numpy(U_normalized).float()
encoded, snapshot_decoded = cae_model(snapshot.to(device_tmp))
with open(model_path/'encoded_ks.npy', 'wb') as f:
    np.save(f, encoded.numpy(force=True))

# %% [markdown]
# #### 3 Plot the CAE results

# %%
# Define constants
N_lyap = int(1/ks_data["lyap"]/(ks_data["dt"]*ks_data["upsample"]))
N_plot = 15*N_lyap
fs = 14
cmap = 'RdBu_r'

# Calculate domain length
domain_length = 8 * np.pi

# Create subplots
fig, axs = plt.subplots(nrows=1, ncols=3, figsize=(
    5, 3), sharey=True)  # Changed ncols to 1
cae_model = cae_model.to(device)
# Encode and decode snapshot
snapshot = torch.from_numpy(U_test_series[:N_plot]).float()
encoded, snapshot_decoded = cae_model(snapshot.to(device))

maxnorm = 3.58
# Extract data
data1 = snapshot.numpy(force=True)[:N_plot, 0, :] * maxnorm
data2 = snapshot_decoded.numpy(force=True)[:N_plot, 0, :] * maxnorm
data3 = data1 - data2

lyapunov_time = ks_data["lyap"] * np.arange(0, 10000, (ks_data["dt"]*ks_data["upsample"]))
# Adjust subplot spacing
plt.subplots_adjust(wspace=-0.05)  #
# Plot data
for i, data in enumerate([data1, data2, data3]):
    axes = axs[i]
    im = axes.imshow(data, aspect='auto', cmap=cmap,
                     extent=[0, 2 * 4 * np.pi, int(lyapunov_time[N_plot]), lyapunov_time[0]])

    axes.set_xlabel('x', fontsize=fs, rotation=0, labelpad=0, y=0.46)
    # Set y-tick labels and font size
    # axes.set_yticks(axes.get_yticks())  # Ensure yticks are set first
    # axes.set_yticklabels(
    #     [f'{int(tick)}' for tick in axes.get_yticks()], fontsize=fs)

    axes.yaxis.tick_left()

    axes.set_xticks(np.arange(0, 8 * np.pi + 0.01, step=(1 * 4 * np.pi)), ['0', r'$4\pi$', r'8$\pi$'],
                    fontsize=fs)
    for tick_label in axes.get_xticklabels():
        tick_label.set_ha('center')
        tick_label.set_x(-0.05)

    # Add colorbar
    if i == 1 or i == 2:
        cbar = fig.colorbar(im, ax=axes)
        cbar.ax.tick_params(labelsize=fs)
axs[0].set_ylabel(r'$\tau_{\lambda}$', fontsize=fs)
axs[0].set_title("Reference")
axs[1].set_title("CAE")
axs[2].set_title("Error")
# Show or save plot
plt.tight_layout()
# plt.savefig("../images/cae.png", dpi=100)
